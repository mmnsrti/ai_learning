# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# training data
X = np.array([[1], [2], [3], [4], [5]])  # hours studied
y = np.array([52, 56, 61, 66, 71])       # exam scores

# model
model = LinearRegression()
model.fit(X, y)

# parameters
print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)

# prediction
pred = model.predict([[6]])
print("Predicted score for 6 hours:", pred[0])
def predict_score(hours):
    return model.predict([[hours]])[0]

print("Predicted score for 7 hours:", predict_score(100))
# Out:
# Slope (m): 4.800000000000001
# Intercept (b): 46.8
# Predicted score for 6 hours: 75.6
# Predicted score for 7 hours: 526.8000000000001
