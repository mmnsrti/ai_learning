# %%
conda list tensorflow
# Out:
# # packages in environment at /home/nosrati/anaconda3/envs/ml_linear_regression:
# #
# # Name                     Version          Build                Channel
# tensorflow                 2.19.1           cpu_py311hbca4264_0
# tensorflow-base            2.19.1           cpu_py311hba389cf_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, random, numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

DATA_DIR = "dataset"  # <-- change if needed
IMG_SIZE = 224
BATCH_SIZE = 32
# Out:
# 2026-01-05 16:25:21.884727: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-05 16:25:21.922252: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
