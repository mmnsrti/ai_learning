# %%
age= 32
color= "red"
name="mehdi"

# %%
print(age,color,name)
print(type(age),type(color),type(name))
# Out:
# 32 red mehdi
# <class 'int'> <class 'str'> <class 'str'>

# %%
a=5
b=3
a=b
print(a)
b=a
print(b)
# Out:
# 3
# 3

# %%
num = 234
result = int(str(num)[::-1])
print(result)
# Out:
# 432
