# %%
num = input("addad vared kon: ")
try:
    val = float(num)
    if val > 0:
        print("mothbat")
    elif val < 0:
        print("manfi.")
    else:
        print("0")
except ValueError:
    print("Eshtebah.")
# Out:
# manfi.

# %%
esme = input("esm khod ra vared konid: ")
names=["ali", "reza", "sara", "fatemeh"]
if esme in names:
    print("esm shoma dar list mojood ast.") 
else:
    print("esm shoma dar list mojood nist.")
# Out:
# esm shoma dar list mojood nist.
